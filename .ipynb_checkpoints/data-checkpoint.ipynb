# %%
print("hello world")

# %%
import pandas as pd

#loading the response data
df = pd.read_csv('Exploring Public Perspectives on the Online Safety Act (Responses) - Form responses 1.csv')

#display first 5 rows
df.head()
# Out:
#              Timestamp  \
# 0  20/10/2025 19:26:55
# 1  20/10/2025 19:29:34
# 2  24/10/2025 13:58:34
# 3  24/10/2025 14:00:10
# 4  24/10/2025 14:07:50
#
#    To what extent do you believe the online safety act makes the internet safer for users from harm?  \
# 0                                                  1
# 1                                                  2
# 2                                                  1
# 3                                                  1
# 4                                                  4
#
#   What types of cyber-harm is the online safety act most effective at addressing?  \
# 0                                  None of the above
# 1                             Child Protection Onine
# 2                                  None of the above
# 3                                  None of the above
# 4  Cyberbullying/Harassment, Illegal Content, Chi...
#
#   Will the Online Safety Act help hold tech companies more accountable for user safety?  \
# ...
